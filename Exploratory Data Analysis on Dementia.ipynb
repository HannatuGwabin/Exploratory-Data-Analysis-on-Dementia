# %% [markdown]
# # Exploratory Data Analysis on Dementia
#
#
# ![dementia.jpg](attachment:dementia.jpg)
#
#
# ## Overview
#
# A neurological condition called Dementia impairs mental processes like memory, thought, and reasoning. It is a chronic ailment that can worsen with time, leaving the sufferer utterly dependent on others and severely impairing daily tasks. An early diagnosis can enhance people with dementia and their caregivers' quality of life.
#
# Exploratory Data Analysis (EDA) is crucial in comprehending and drawing conclusions from a dataset, especially when researching complicated phenomena like dementia. EDA enables researchers and analysts to find patterns, correlations, and hidden elements within the data, leading to a greater understanding of the condition. It does this by utilizing a variety of statistical and visualization tools. EDA can assist in revealing essential details about the demographic attributes, risk factors, progression patterns, and potential predictive factors connected to the disease when analyzing a dataset on dementia.
#
#
# ## Objective
#
# The objective of this project is to explore every feature in the dataset using Exploratory Data Analysis (EDA) to gain insights from the data.

# %%
# import our libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# import our dataset

data = pd.read_csv(r'C:\Users\ASUS\Desktop/dementia_dataset.csv')

# %%
# Have a look at our first five dataframe

data.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
# Have a look at our last five dataframe

data.tail()
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 368    16  1.0  28.0  0.5  1693  0.694  1.037
# 369    16  1.0  26.0  0.5  1688  0.675  1.040
# 370    13  2.0  30.0  0.0  1319  0.801  1.331
# 371    13  2.0  30.0  0.0  1327  0.796  1.323
# 372    13  2.0  30.0  0.0  1333  0.801  1.317

# %%
# Renaming the variables to their actual meaning

data.rename(columns={'M/F':'Gender','MR Delay':'MR_Delay', 'Hand':'Handedness', 'EDUC':'Years_of_Edu',
         'SES':'Socioeconomic_Status', 'MMSE':'Mini_Mental_State_Exam',
         'CDR':'Clinical_Dementia_Rating', 'eTIV':'Estimated_total_intracranial_volume',
        'nWBV':'Normalized_whole_brain_volume', 'ASF':'Atlas_scaling_factor'}, 
      inplace=True)

# %%
data.drop_duplicates()
# Out:
#     Subject ID         MRI ID        Group  Visit  MR_Delay Gender Handedness  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0      M          R
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457      M          R
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1         0      M          R
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2       560      M          R
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3      1895      M          R
# ..         ...            ...          ...    ...       ...    ...        ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842      M          R
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297      M          R
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0      F          R
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763      F          R
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608      F          R
#
# ...

# %%
# Descriptive analysis

data.describe()
# Out:
#             Visit     MR_Delay         Age  Years_of_Edu  \
# count  373.000000   373.000000  373.000000    373.000000
# mean     1.882038   595.104558   77.013405     14.597855
# std      0.922843   635.485118    7.640957      2.876339
# min      1.000000     0.000000   60.000000      6.000000
# 25%      1.000000     0.000000   71.000000     12.000000
# 50%      2.000000   552.000000   77.000000     15.000000
# 75%      2.000000   873.000000   82.000000     16.000000
# max      5.000000  2639.000000   98.000000     23.000000
#
#        Socioeconomic_Status  Mini_Mental_State_Exam  Clinical_Dementia_Rating  \
# count            354.000000              371.000000                373.000000
# mean               2.460452               27.342318                  0.290885
# std                1.134005                3.683244                  0.374557
# min                1.000000                4.000000                  0.000000
# ...

# %%
# number of rows and columns

data.shape
# Out:
# (373, 15)

# %%
# Check our data information

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Subject ID                           373 non-null    object
#  1   MRI ID                               373 non-null    object
#  2   Group                                373 non-null    object
#  3   Visit                                373 non-null    int64
#  4   MR_Delay                             373 non-null    int64
#  5   Gender                               373 non-null    object
#  6   Handedness                           373 non-null    object
#  7   Age                                  373 non-null    int64
#  8   Years_of_Edu                         373 non-null    int64
#  9   Socioeconomic_Status                 354 non-null    float64
#  10  Mini_Mental_State_Exam               371 non-null    float64
# ...

# %%
# check for missing values

data.isnull().sum()
# Out:
# Subject ID                              0
# MRI ID                                  0
# Group                                   0
# Visit                                   0
# MR_Delay                                0
# Gender                                  0
# Handedness                              0
# Age                                     0
# Years_of_Edu                            0
# Socioeconomic_Status                   19
# Mini_Mental_State_Exam                  2
# Clinical_Dementia_Rating                0
# Estimated_total_intracranial_volume     0
# Normalized_whole_brain_volume           0
# Atlas_scaling_factor                    0
# dtype: int64

# %%
# Use backwardfill to fill the missing values

data['Socioeconomic_Status'].bfill(inplace=True)

# %%
data['Mini_Mental_State_Exam'].bfill(inplace=True)

# %%
data.isnull().sum()
# Out:
# Subject ID                             0
# MRI ID                                 0
# Group                                  0
# Visit                                  0
# MR_Delay                               0
# Gender                                 0
# Handedness                             0
# Age                                    0
# Years_of_Edu                           0
# Socioeconomic_Status                   0
# Mini_Mental_State_Exam                 0
# Clinical_Dementia_Rating               0
# Estimated_total_intracranial_volume    0
# Normalized_whole_brain_volume          0
# Atlas_scaling_factor                   0
# dtype: int64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # Univariate Analysis

# %%
# distribution of Group 'Demented', 'Nondemented', and 'Converted'

plt.figure(figsize=(10,6))
ax=sns.countplot(x= 'Group', data= data)

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see that the dataset is not balance. Our target variable is Demented but we can see that Non-demented has a more significant value of 50.9%.

# %%
# distribution of Socioeconomic Status

plt.figure(figsize=(10,6))
ax=sns.countplot(x= 'Socioeconomic_Status', data= data)

# add percentages to the bars
total = float(len(data['Socioeconomic_Status']))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see that from the graph that Socioeconomic status has five levels and also has a way of affecting people with Dementia. A more significant number of people with 29.8% are on level 2 which is high SES status while 2.4% have Low SES. Low Socioeconomic status  has been identified as a risk factor for the development of dementia.

# %%
# distribution of Years of Education

plt.figure(figsize=(10,6))
ax=sns.countplot(x= 'Years_of_Edu', data= data)

# add percentages to the bars
total = float(len(data['Years_of_Edu']))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see that about 27.6% have 12 years of Education followed by 16 years of Education with 21.7%.

# %%
# distribution of Handedness

plt.figure(figsize=(6,5))
ax=sns.countplot(x= 'Handedness', data= data)

# add percentages to the bars
total = float(len(data['Handedness']))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see that 100% are Right handed.

# %%
# distribution of Visit

plt.figure(figsize=(10,6))
ax=sns.countplot(x= 'Visit', data= data)

# add percentages to the bars
total = float(len(data['Visit']))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see a wider distribution of about 40.2% of those that were visited once followed by 38.6% of people that were visited twice.

# %%
# distribution of Age

plt.figure(figsize=(10,6))
ax=sns.histplot (x= 'Age', binwidth= 5, data= data);

# add percentages to the bars
total = float(len(data['Age']))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see there is more distribution around 70 years - 85 years.

# %%
# distribution of Clinical Dementia Rating

plt.figure(figsize=(10,6))
ax=sns.countplot(x= 'Clinical_Dementia_Rating', data= data)

# add percentages to the bars
total = float(len(data['Clinical_Dementia_Rating']))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# Observation: For this dataset, the CDR is based on a scale of 0–2: no dementia (CDR = 0), questionable dementia (CDR = 0.5), MCI (CDR = 1), moderate cognitive impairment (CDR = 2).
#
# #### 52.2% have a CDR scale of 0, Which implies no Dementia.
# #### 33.0% have a CDR scale of 0.5, Which implies questionable Dementia.
# #### 11.0% have a CDR scale of 1, Which implies Moderate Dementia.
# #### 0.8% have a CDR scale of 2, Which implies Severe Dementia.

# %%
# distribution of Mini_Mental_State_Exam

plt.figure(figsize=(15,8))
ax=sns.countplot (x= 'Mini_Mental_State_Exam', data= data);
# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation:The MMSE allows for a maximum score of 30. A score of 25 or higher is classed as normal. If the score is below 24, the result is usually considered to be abnormal, indicating possible cognitive impairment.
# #### We can from our data that a more significant value have a score of 30 which is higher than 25 and considered normal while the others lower than 24 are considered abnormal.

# %% [markdown]
# # Bivariate Analysis

# %%
# What Gender is more at risk for Dementia?

plt.figure(figsize=(8,6))
ax=sns.countplot(x='Gender', hue='Group',data = data);

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation:  We can see a significant number of Demented people with 23.1% in Male while Female has 16.2%. But Studies have shown that Women have a greater risk of developing dementia during their lifetime. The main reason for this greater risk is because women live longer than men and old age is the biggest risk factor for this disease so this data could be as a result of other factors.

# %%
# How does Gender and Age impact Dementia?

plt.figure(figsize=(8,5))
ax=sns.barplot(x='Gender', y='Age',data = data);

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: There is no much difference in the age distribution between the females having 20.7% and the males having 20.6%. This means both gender are affected by Dementia but the females are affected more when it come to age.

# %%
# what impact does Age have on Dementia?

sns.boxplot(x='Group', y='Age',data=data);

# %% [markdown]
# #### Observation: (1) There is higher median in the Converted group, followed by Non-demented and then Demented group.
# #### (2) We can see an outlier in the Demented group (98 years).
# #### (3) We can see that those with Dementia are between 61 - 97 years.

# %%
# What inmpact does Visit have on Demented group?

plt.figure(figsize=(10,7))
ax=sns.countplot(x='Visit',hue='Group', data = data);

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see fom the data that 17.2% of people with Dementia were mostly visited once a day, followed by Demented patients who were visited twice a day.

# %%
# Distribution of Group by Mini_Mental_State_Exam 

sns.boxplot(x='Group', y='Mini_Mental_State_Exam',data=data);

# %% [markdown]
# #### Observation: We can see the Mini state exam Score of the group Non-demented are at 30 which is considered normal. Mini state exam Scores of 25-30 out of 30 are considered normal, 21-24 as mild, 10-20 as moderate and below 10 as severe impairment.

# %%
# Distribution of Dementia by Clinical_Dementia_Rating 

plt.figure(figsize=(10,5))
ax=sns.countplot(x='Clinical_Dementia_Rating', hue='Group',data=data);

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: 27.3% have a CDR scale of 0.5, Which implies questionable Dementia.
# #### 11.0% have a CDR scale of 1.0, Which implies Moderate Dementia.
# #### 0.8% have a CDR scale of 2.0, Which implies Severe Dementia.

# %%
# what effect does Socioeconomic status have on people with Dementia?

sns.boxplot(x='Group', y='Socioeconomic_Status',data=data);

# %% [markdown]
# #### Observation: We can see from the visualized data that those with Dementia have low Socio-economic status of 5.0 with a median value of 3.0. Low Socioeconomic status  has been identified as a risk factor for the development of dementia.
# #### Poverty is considered a risk factor for declines in mental health among older people. Those at the lower levels of socioeconomic status are often most likely to be diagnosed with a psychological disorder.

# %%
# Distribution of Group by Normalized_whole_brain_volume 

sns.boxplot(x='Group', y='Normalized_whole_brain_volume',data=data);

# %% [markdown]
# #### Observation: We can see people with Dementia have a small spread of distribution compared to other groups. According to studies, people with dementia have a significant loss of brain volume.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(data)

# %%
corel = data.corr()
corel
# Out:
#                                         Visit  MR_Delay       Age  \
# Visit                                1.000000  0.920009  0.183213
# MR_Delay                             0.920009  1.000000  0.205357
# Age                                  0.183213  0.205357  1.000000
# Years_of_Edu                         0.024615  0.051630 -0.027886
# Socioeconomic_Status                -0.057090 -0.033785 -0.032357
# Mini_Mental_State_Exam              -0.033152  0.063271  0.056240
# Clinical_Dementia_Rating             0.002325 -0.062915 -0.026257
# Estimated_total_intracranial_volume  0.117428  0.119624  0.042348
# Normalized_whole_brain_volume       -0.126682 -0.105586 -0.518359
# Atlas_scaling_factor                -0.120399 -0.123545 -0.035067
#
#                                      Years_of_Edu  Socioeconomic_Status  \
# Visit                                    0.024615             -0.057090
# MR_Delay                                 0.051630             -0.033785
# ...

# %%
corel = data.corr()
sns.heatmap(corel, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation: There is a strong correlation between Visit and MR_Delay.
